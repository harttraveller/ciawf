# %%
import json
import requests
from ciawf.env import COUNTRIES_PAGE_DATA_URL

# %%
requests.get(COUNTRIES_PAGE_DATA_URL).json()["result"]["data"]["countries"]
# Out:
# {'edges': [{'node': {'title': 'Afghanistan',
#     'code': 'AF',
#     'uri': '/countries/afghanistan/',
#     'redirect': '',
#     'summaryDocument': None,
#     'travelDocument': None}},
#   {'node': {'title': 'Akrotiri',
#     'code': 'AX',
#     'uri': '/countries/akrotiri/',
#     'redirect': '',
#     'summaryDocument': None,
#     'travelDocument': None}},
#   {'node': {'title': 'Albania',
#     'code': 'AL',
#     'uri': '/countries/albania/',
#     'redirect': '',
#     'summaryDocument': None,
#     'travelDocument': None}},
#   {'node': {'title': 'Algeria',
#     'code': 'AG',
#     'uri': '/countries/algeria/',
#     'redirect': '',
#     'summaryDocument': None,
#     'travelDocument': None}},
#   {'node': {'title': 'American Samoa',
#     'code': 'AQ',
#     'uri': '/countries/american-samoa/',
#     'redirect': '',
#     'summaryDocument': None,
#     'travelDocument': None}},
#   {'node': {'title': 'Andorra',
#     'code': 'AN',
#     'uri': '/countries/andorra/',
# ...
